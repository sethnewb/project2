# %%
# Import dependencies
import json
import pandas as pd
import sqlite3
import pprint as pp

# Create the connection string to the sqllite database
con = sqlite3.connect("db/olympic_data.db")

# Using SQL, select all records from the athlete_events table
sql = f"""
    SELECT * FROM athlete_events
    """
# Read the table into a PANDAS dataframe
ath_df = pd.read_sql(sql, con)
ath_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball  None
# 1      Judo Men's Extra-Lightweight  None
# 2           Football Men's Football  None
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres  None

# %%
# Grabbing only the columns needed for the sunburst viz
clean_ath_df = ath_df[['Season','Sport','Team','Medal','Year']]
clean_ath_df.head()
# Out:
#    Season          Sport            Team Medal  Year
# 0  Summer     Basketball           China  None  1992
# 1  Summer           Judo           China  None  2012
# 2  Summer       Football         Denmark  None  1920
# 3  Summer     Tug-Of-War  Denmark/Sweden  Gold  1900
# 4  Winter  Speed Skating     Netherlands  None  1988

# %%
# Filtering data for 2016 only to test the "to_json" function
filt_clean_df = clean_ath_df.loc[clean_ath_df['Year'] >= 2014]
fcdf = filt_clean_df.reset_index(drop=True)

# %%
# Convert the dataframe into a json object
# j = filt_clean_df.to_json()

# %%
# Print the json object
# print(json.dumps(json.loads(j), indent=2, sort_keys=False)).head()

# %%
# Extracting unique values from each column of the dataframe and putting them in a list
unique_seasons = fcdf.Season.unique()
unique_sports = fcdf.Sport.unique()
unique_teams = fcdf.Team.unique()
unique_medals = fcdf.Medal.unique()
unique_years = fcdf.Year.unique()

seasons_list = unique_seasons.tolist()
sports_list = unique_sports.tolist()
teams_list = unique_teams.tolist()
medals_list = unique_medals.tolist()
years_list = unique_years.tolist()

# %%
# Testing creating format of JSON object we need manually...
newDict = {}
newDict.update({"name":"Olympics"})
newDict.update({"children":[
    {"name":unique_seasons[0]},
    {"name":unique_seasons[1]}
]})

# %%
print(json.dumps(newDict, indent=4))
# Out:
# {
#     "name": "Olympics",
#     "children": [
#         {
#             "name": "Winter"
#         },
#         {
#             "name": "Summer"
#         }
#     ]
# }

# %%
# Sort columns to be extracted into CSV
sort_clean_ath_df = clean_ath_df.sort_values(['Season', 'Sport', 'Team', 'Medal', 'Year'], ascending=[True, True, True, True, True])
sort_clean_ath_df
# Out:
#         Season          Sport            Team   Medal  Year
# 214105  Summer    Aeronautics     Switzerland    Gold  1936
# 213142  Summer       Alpinism         Germany    Gold  1932
# 213208  Summer       Alpinism         Germany    Gold  1932
# 60639   Summer       Alpinism     Switzerland    Gold  1936
# 60641   Summer       Alpinism     Switzerland    Gold  1936
# 244966  Summer        Archery  American Samoa    None  2000
# 18304   Summer        Archery       Argentina    None  1988
# 180139  Summer        Archery       Argentina    None  1988
# 46941   Summer        Archery       Australia  Bronze  2004
# 192202  Summer        Archery       Australia  Bronze  2016
# 245485  Summer        Archery       Australia  Bronze  2016
# 263042  Summer        Archery       Australia  Bronze  2016
# 66067   Summer        Archery       Australia    Gold  2000
# 57445   Summer        Archery       Australia    None  1972
# 198631  Summer        Archery       Australia    None  1972
# 237432  Summer        Archery       Australia    None  1972
# 1488    Summer        Archery       Australia    None  1976
# 7621    Summer        Archery       Australia    None  1976
# 198632  Summer        Archery       Australia    None  1976
# 242732  Summer        Archery       Australia    None  1976
# 57446   Summer        Archery       Australia    None  1980
# 59645   Summer        Archery       Australia    None  1980
# 242733  Summer        Archery       Australia    None  1980
# 22956   Summer        Archery       Australia    None  1984
# 57447   Summer        Archery       Australia    None  1984
# 22957   Summer        Archery       Australia    None  1988
# 22958   Summer        Archery       Australia    None  1988
# 66061   Summer        Archery       Australia    None  1988
# 66062   Summer        Archery       Australia    None  1988
# 255479  Summer        Archery       Australia    None  1988
# ...        ...            ...             ...     ...   ...
# 160057  Winter  Speed Skating    West Germany    None  1988
# 160058  Winter  Speed Skating    West Germany    None  1988
# 174680  Winter  Speed Skating    West Germany    None  1988
# 174681  Winter  Speed Skating    West Germany    None  1988
# 230571  Winter  Speed Skating    West Germany    None  1988
# 230572  Winter  Speed Skating    West Germany    None  1988
# 116132  Winter  Speed Skating      Yugoslavia    None  1984
# 116133  Winter  Speed Skating      Yugoslavia    None  1984
# 116134  Winter  Speed Skating      Yugoslavia    None  1984
# 116135  Winter  Speed Skating      Yugoslavia    None  1984
# 156987  Winter  Speed Skating      Yugoslavia    None  1984
# 156988  Winter  Speed Skating      Yugoslavia    None  1984
# 156989  Winter  Speed Skating      Yugoslavia    None  1984
# 156990  Winter  Speed Skating      Yugoslavia    None  1984
# 255125  Winter  Speed Skating      Yugoslavia    None  1984
# 255126  Winter  Speed Skating      Yugoslavia    None  1984
# 255127  Winter  Speed Skating      Yugoslavia    None  1984
# 270956  Winter  Speed Skating      Yugoslavia    None  1984
# 270957  Winter  Speed Skating      Yugoslavia    None  1984
# 116136  Winter  Speed Skating      Yugoslavia    None  1988
# 116137  Winter  Speed Skating      Yugoslavia    None  1988
# 116138  Winter  Speed Skating      Yugoslavia    None  1988
# 156991  Winter  Speed Skating      Yugoslavia    None  1988
# 156992  Winter  Speed Skating      Yugoslavia    None  1988
# 156993  Winter  Speed Skating      Yugoslavia    None  1988
# 37570   Winter  Speed Skating      Yugoslavia    None  1992
# 37571   Winter  Speed Skating      Yugoslavia    None  1992
# 37572   Winter  Speed Skating      Yugoslavia    None  1992
# 139040  Winter  Speed Skating      Yugoslavia    None  1992
# 139041  Winter  Speed Skating      Yugoslavia    None  1992
#
# [271116 rows x 5 columns]

# %%
# Convert to csv
sort_clean_ath_df.to_csv("clean_athlete_data.csv",encoding="utf-8", index=False)

# %%
##############################################
## New Tables for Medals by Country by Year ##
##############################################

# %%
removeNone = ath_df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
removeNone.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season    City       Sport  \
# 40  2014 Winter  2014  Winter   Sochi  Ice Hockey
# 41  1948 Summer  1948  Summer  London  Gymnastics
# 42  1948 Summer  1948  Summer  London  Gymnastics
# 44  1948 Summer  1948  Summer  London  Gymnastics
# 48  1948 Summer  1948  Summer  London  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# 44            Gymnastics Men's Horse Vault    Gold
# 48        Gymnastics Men's Pommelled Horse    Gold

# %%
removeNone["Medal"].value_counts()
# Out:
# Gold      10167
# Bronze    10148
# Silver     9866
# Name: Medal, dtype: int64

# %%
removeNone["NOC"].value_counts()
# Out:
# USA    4383
# URS    2246
# GER    1612
# AUS    1206
# RUS    1134
# ITA    1060
# CAN    1060
# GBR    1031
# GDR     995
# FRA     987
# CHN     985
# JPN     843
# HUN     791
# SWE     765
# FIN     724
# NED     708
# ROU     597
# FRG     582
# KOR     561
# POL     548
# NOR     514
# BRA     447
# ESP     431
# CUB     394
# TCH     375
# SUI     345
# BUL     328
# YUG     321
# AUT     273
# DEN     255
#        ...
# ECU       2
# UAE       2
# LIB       2
# TAN       2
# MOZ       2
# AFG       2
# SYR       2
# KUW       2
# GUA       1
# MRI       1
# CYP       1
# NIG       1
# TOG       1
# HAI       1
# SRI       1
# GAB       1
# ERI       1
# GUY       1
# SEN       1
# ZAM       1
# KOS       1
# ISV       1
# BOT       1
# BAR       1
# MKD       1
# JOR       1
# TGA       1
# DJI       1
# BER       1
# SUD       1
# Name: NOC, Length: 143, dtype: int64

# %%
# New Dataframe to count medals by Country
countryMedals = removeNone[["NOC","Medal"]]
gr_countryMedals = countryMedals.groupby(["NOC"])
newDf = pd.DataFrame(gr_countryMedals["Medal"].count())
ri_newDf = newDf.reset_index()
ri_newDf
# Out:
#      NOC  Medal
# 0    AFG      2
# 1    ALG     15
# 2    ANZ      4
# 3    ARG    220
# 4    ARM     15
# 5    AUS   1206
# 6    AUT    273
# 7    AZE     44
# 8    BAH     40
# 9    BAR      1
# 10   BDI      2
# 11   BEL     89
# 12   BER      1
# 13   BLR    131
# 14   BOT      1
# 15   BRA    447
# 16   BRN      3
# 17   BUL    328
# 18   CAN   1060
# 19   CHI     25
# 20   CHN    985
# 21   CIV      3
# 22   CMR     18
# 23   COL     27
# 24   CRC      4
# 25   CRO    139
# 26   CUB    394
# 27   CYP      1
# 28   CZE    144
# 29   DEN    255
# ..   ...    ...
# 113  SRI      1
# 114  SUD      1
# 115  SUI    345
# 116  SUR      2
# 117  SVK     47
# 118  SWE    765
# 119  SYR      2
# 120  TAN      2
# 121  TCH    375
# 122  TGA      1
# 123  THA     30
# 124  TJK      4
# 125  TOG      1
# 126  TPE     49
# 127  TTO     29
# 128  TUN     12
# 129  TUR     70
# 130  UAE      2
# 131  UGA      7
# 132  UKR    194
# 133  URS   2246
# 134  URU     24
# 135  USA   4383
# 136  UZB     34
# 137  VEN     15
# 138  VIE      4
# 139  WIF      5
# 140  YUG    321
# 141  ZAM      1
# 142  ZIM     22
#
# [143 rows x 2 columns]

# %%
# New DataFrame to count medals by Country by Year
countryMedalsByYear = removeNone[["NOC","Year","Medal"]]
gr2_countryMedals = countryMedalsByYear.groupby(["NOC","Year"])
newDf2 = pd.DataFrame(gr2_countryMedals["Medal"].count())
newDf2
sri_newDf2 = newDf2.sort_values(['Year','NOC']).reset_index()
cleanDf2 = sri_newDf2.groupby(['Year','NOC']).sum().groupby(level=[1]).cumsum()
reset_cleanDf2 = cleanDf2.reset_index()
reset_cleanDf2
# Out:
#       Year  NOC  Medal
# 0     1896  GBR      2
# 1     1896  GER      6
# 2     1896  USA     12
# 3     1900  AUS      4
# 4     1900  CAN      2
# 5     1900  FRA      4
# 6     1900  GBR      6
# 7     1900  HUN      3
# 8     1900  USA     33
# 9     1904  CAN      5
# 10    1904  GBR      7
# 11    1904  GER     10
# 12    1904  GRE      1
# 13    1904  HUN      5
# 14    1904  USA     81
# 15    1906  AUT      2
# 16    1906  CAN      6
# 17    1906  FIN      4
# 18    1906  FRA      6
# 19    1906  GBR     18
# 20    1906  GER     19
# 21    1906  GRE      5
# 22    1906  HUN      7
# 23    1906  ITA      1
# 24    1906  SWE     11
# 25    1906  USA    103
# 26    1908  ANZ      3
# 27    1908  BEL      1
# 28    1908  CAN     17
# 29    1908  FIN     10
# ...    ...  ...    ...
# 1271  2016  NIG      1
# 1272  2016  NOR    514
# 1273  2016  NZL    211
# 1274  2016  PHI      8
# 1275  2016  POL    548
# 1276  2016  POR     25
# 1277  2016  PRK     58
# 1278  2016  PUR      8
# 1279  2016  QAT      5
# 1280  2016  ROU    597
# 1281  2016  RSA     69
# 1282  2016  RUS   1134
# 1283  2016  SGP      9
# 1284  2016  SLO     47
# 1285  2016  SRB     85
# 1286  2016  SUI    345
# 1287  2016  SVK     47
# 1288  2016  SWE    765
# 1289  2016  THA     30
# 1290  2016  TJK      4
# 1291  2016  TPE     49
# 1292  2016  TTO     29
# 1293  2016  TUN     12
# 1294  2016  TUR     70
# 1295  2016  UAE      2
# 1296  2016  UKR    194
# 1297  2016  USA   4383
# 1298  2016  UZB     34
# 1299  2016  VEN     15
# 1300  2016  VIE      4
#
# [1301 rows x 3 columns]

# %%
con = sqlite3.connect("db/olympic_data.db")
newDf.to_sql("medals_by_country", con, if_exists="replace", index=False)
reset_cleanDf2.to_sql("medals_by_country_by_year", con, if_exists="replace",index=False)

con.commit()
con.close()

# %%
# Create CSVs - this was for testing
# ri_newDf.to_csv("medals_by_country.csv",encoding="utf-8", index=False)
# reset_cleanDf2.to_csv("medals_by_country_by_year.csv",encoding="utf-8", index=False)
